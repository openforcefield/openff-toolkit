# %% [markdown]
# # Compare SMIRFF vs parm@frosst
#
# For a specified set of molecules for which we already have (or can easily generate) parm@frosst parameters in AMBER format, compare single-point energies for the molecules from a specified SMIRFF with those from parm@frosst parameters. This also attempts to do a detailed breakdown of energy differences by force type, and then drill down to find specific atom indices involved in the forces for which there are substantial differences.
#
# This is to address this issue as raised on GitHub: https://github.com/open-forcefield-group/smarty/issues/123
#
# **Major steps**:
# 1. Obtain set of molecules
#     1. Prep sets of molecules by generating mol2 files with (a) TRIPOS types, and (b) parm@frosst types
# 2. Obtain parm@frosst parameters for these molecules (current options only AlkEthOH (this repo) or the MMFF94 or ZINC test sets from http://www.ccl.net/cca/data/parm_at_Frosst/ ).
# 3. Evaluate energies for all molecules from both sets of parameters in OpenMM
#    1. Get total energy comparison
#    2. Compare breakdown by force type
#    3. Compare breakdown by specific atoms
#
#
# ## 1. Obtain set(s) of molecules
#
# We'll use the ZINC (and later, MMFF94) subsets from the CCL link above. These were already downloaded into this directory from that site. Some supplemental files were provided by Christopher Bayly.
#
# ### 1.A. Prep molecule sets

# %%
# Imports
import openeye.oechem as oechem
import os
import commands
from tleap_tools import *
import simtk.unit as unit

# Start with zinc set
# Load with TRIPOS names
infile = 'zinc-subset-tripos.mol2.gz'
istream = oechem.oemolistream(infile)
mol = oechem.OEMol()
oemols_tripos = []
while oechem.OEReadMolecule(istream, mol):
    oemols_tripos.append(oechem.OEMol(mol))
istream.close()
    
# Load with parm@frosst names
infile = 'zinc-subset-parm@frosst.mol2.gz'
flavor = oechem.OEIFlavor_Generic_Default | oechem.OEIFlavor_MOL2_Default | oechem.OEIFlavor_MOL2_Forcefield
istream = oechem.oemolistream(infile)
istream.SetFlavor( oechem.OEFormat_MOL2, flavor)
mol = oechem.OEMol()
oemols_frosst = []
while oechem.OEReadMolecule(istream, mol):
    oemols_frosst.append(oechem.OEMol(mol))
istream.close()

print("%s molecules found" % len(oemols_tripos))
# Out:
# 7505 molecules found

# %% [markdown]
# ## 2. Obtain parm@frosst parameters for these molecules if not already available
#
# We either (a) already have these molecules parameterized in the repo (if we've done this before) or we need to generate them by going through tleap and parameterizing. In either case we need to actually have the parameter files sitting here to proceed to the next step, so here we'll do that.

# %%
# If we already have the parameters in an archive file, just extract
if os.path.isfile('zinc_frosst_amber.tar.gz') and not os.path.isdir('zinc_frosst_amber'):
    commands.getoutput('tar -xvf zinc_frosst_amber.tar.gz')
    file = open('zinc_frosst_amber/failed_idxs.txt', 'r')
    text = file.readlines()
    failed_idxs = [ int(line.split()[0].strip()) for line in text ]
    file.close()
elif os.path.isdir('zinc_frosst_amber'):
    file = open('zinc_frosst_amber/failed_idxs.txt', 'r')
    text = file.readlines()
    failed_idxs = [ int(line.split()[0].strip()) for line in text ]
    file.close()
    
# Otherwise we have to generate
else:
    # Do directory bookkeeping
    mol2dir = 'zinc_frosst_mol2'
    amberdir = 'zinc_frosst_amber'
    commands.getoutput('rm -r %s' % mol2dir)
    commands.getoutput('rm -r %s' % amberdir)
    os.mkdir(mol2dir)
    os.mkdir(amberdir)
    
    # Generate molecule IDs
    molids = ['zinc%d' %nr for nr in range(len(oemols_tripos))]
    
    # Make parm@frosst mol2 files for each individual molecule
    for (idx, mol) in enumerate(oemols_frosst):
        ostream = oechem.oemolostream(os.path.join(mol2dir, molids[idx]+'.mol2'))
        ostream.SetFlavor( oechem.OEFormat_MOL2, flavor)
        oechem.OEWriteMolecule(ostream, mol)
    
    # parameterize using tleap, parm99, and files provided with parm@frosst from CCL
    frcmod = 'parm_at_Frosst/parm_Frosst.frcmod'
    failed_idxs = []
    for (idx, molid) in enumerate(molids):
        mol2file = os.path.join( mol2dir, molids[idx]+'.mol2')
        prmtop = os.path.join( amberdir, molids[idx]+'.prmtop')
        crd = os.path.join( amberdir, molids[idx]+'.crd')
        print("Setting up %s..." % molid)
        startdir = os.getcwd()
        try:
            run_tleap( molid, mol2file, frcmod, prmtop, crd)
        except RuntimeError:
            failed_idxs.append(idx)
        except IOError:
            failed_idxs.append(idx)
            print("Failed %s..." % idx)
        os.chdir(startdir)
    # Create archive file containing parameters and list of molecule indexes which failed
    commands.getoutput('tar -cvf zinc_frosst_amber.tar zinc_frosst_amber')
    commands.getoutput('gzip zinc_frosst_amber.tar')
    
    # Clean up unneeded directories
    commands.getoutput('rm -r %s' % amberdir)
    commands.getoutput('rm -r %s' % mol2dir)
    
    # Print info on what was parameterized successfully
    print("Successfully parameterized %s molecules out of %s" % (len(oemols_tripos)-len(failed_idxs), len(oemols_tripos)))
    
    # Store indices which failed
    file = open('parm_at_Frosst/failed_idxs.txt', 'w')
    for idx in failed_idxs:
        file.write('%s\n' % idx)
    file.close()
    
print("%s molecules failed." % len(failed_idxs))
# Out:
# 3576 molecules failed.

# %% [markdown]
# ## 3. Evaluate/compare energies for both sets of molecules from OpenMM
#
# ### 3A-B: Compare overall and component energies
# Use only the molecules for which we already have both formats available and proceed to energies
#
# #### Begin by extracting overall and component energies
# Note that this will take a few minutes for the zinc set.

# %%
from smarty.forcefield_utils import *
from smarty.forcefield import *
import os

# Invert list of failed indexes to find molecules we succeeded on
mol_idxs = [ idx for idx in range(len(oemols_tripos)) if not idx in failed_idxs]
print("Processing %s molecules..." % len(mol_idxs))

# Where are AMBER files?
amberdir = 'zinc_frosst_amber'

# Load forcefield
ff = ForceField('../convert_frosst/example_plusgeneric.ffxml')

# Storage for energies and components
frosst_energies={}
frosst_components={}
smirff_energies = {}
smirff_components={}

# Loop over successful molecules and do energy comparisons
for idx in mol_idxs:
    oemol = oemols_tripos[idx]
    prmtop = os.path.join(amberdir, 'zinc%s.prmtop' % idx)
    crd = os.path.join(amberdir, 'zinc%s.crd' % idx)
    frosst_components[idx], smirff_components[idx], frosst_energies[idx], smirff_energies[idx] = compare_molecule_energies(prmtop, crd, ff, oemol, skip_assert = True, verbose = False)

print("Processed.")
# Out:
# Processing 3929 molecules...
# Processed.

# %% [markdown]
# #### Now find all molecules where energy differs by more than some specified cutoff and highlight what components are responsible

# %%
# Set tolerance for significant differences in energy
energy_tol = simtk.unit.Quantity(value = 5, unit = unit.kilocalorie_per_mole)
# Set tolerance for components where differences are significant
component_tol = energy_tol*0.8

# Store which are out of tolerance
components_out_of_tolerance = {}

# Check and store
for idx in mol_idxs:
    diff = np.abs( frosst_energies[idx] - smirff_energies[idx])
    if diff > energy_tol:
        # Print info
        print("Molecule %s has energy difference of %s; out of tolerance." % (idx, diff.in_units_of(unit.kilocalorie_per_mole)))
        # Check components and store any out of tolerance
        components_out_of_tolerance[idx] = []
        for comp in frosst_components[idx]:
            cdiff = np.abs( frosst_components[idx][comp] - smirff_components[idx][comp])
            if cdiff > component_tol:
                components_out_of_tolerance[idx].append(comp)
                print("   Component %s differs by %s..." % (comp, cdiff.in_units_of(unit.kilocalorie_per_mole)))
    else: print("Molecule %s in tolerance" % idx)
# Out:
# Molecule 0 has energy difference of 106334.691068 kcal/mol; out of tolerance.
#    Component nb differs by 4.80134667647 kcal/mol...
#    Component torsion differs by 209.560269613 kcal/mol...
#    Component angle differs by 99717.8988342 kcal/mol...
#    Component bond differs by 6412.03331048 kcal/mol...
# Molecule 1 has energy difference of 95421.9240024 kcal/mol; out of tolerance.
#    Component nb differs by 6.18872813276 kcal/mol...
#    Component torsion differs by 2252.84382604 kcal/mol...
#    Component angle differs by 87022.6495127 kcal/mol...
#    Component bond differs by 6152.61939178 kcal/mol...
# Molecule 6 has energy difference of 108986.622669 kcal/mol; out of tolerance.
#    Component nb differs by 5.83673402802 kcal/mol...
#    Component torsion differs by 944.18854456 kcal/mol...
#    Component angle differs by 101764.958117 kcal/mol...
#    Component bond differs by 6283.31274147 kcal/mol...
# Molecule 13 has energy difference of 168334.393625 kcal/mol; out of tolerance.
#    Component nb differs by 28.8391316485 kcal/mol...
#    Component torsion differs by 6883.24702549 kcal/mol...
#    Component angle differs by 150133.517104 kcal/mol...
#    Component bond differs by 11346.4686269 kcal/mol...
# Molecule 16 has energy difference of 93887.4708594 kcal/mol; out of tolerance.
#    Component nb differs by 10.4731151852 kcal/mol...
#    Component torsion differs by 1683.43632051 kcal/mol...
#    Component angle differs by 85152.1233395 kcal/mol...
#    Component bond differs by 7062.38431465 kcal/mol...
# Molecule 18 has energy difference of 100396.492168 kcal/mol; out of tolerance.
#    Component torsion differs by 2649.88898722 kcal/mol...
#    Component angle differs by 90408.2654809 kcal/mol...
#    Component bond differs by 7341.01778103 kcal/mol...
# Molecule 21 has energy difference of 101904.763282 kcal/mol; out of tolerance.
#    Component nb differs by 20.75540805 kcal/mol...
#    Component torsion differs by 1257.65975301 kcal/mol...
#    Component angle differs by 94481.3121996 kcal/mol...
#    Component bond differs by 6186.54673752 kcal/mol...
# Molecule 24 has energy difference of 138824.809182 kcal/mol; out of tolerance.
#    Component nb differs by 7.49381097079 kcal/mol...
#    Component torsion differs by 3079.21431476 kcal/mol...
#    Component angle differs by 128775.57594 kcal/mol...
#    Component bond differs by 6977.51273854 kcal/mol...
# Molecule 25 has energy difference of 104197.523252 kcal/mol; out of tolerance.
#    Component nb differs by 10.8098949961 kcal/mol...
#    Component torsion differs by 303.281530125 kcal/mol...
#    Component angle differs by 98703.0290372 kcal/mol...
#    Component bond differs by 5202.02257925 kcal/mol...
# Molecule 26 has energy difference of 128388.715129 kcal/mol; out of tolerance.
#    Component nb differs by 27.4329277227 kcal/mol...
#    Component torsion differs by 2100.03455337 kcal/mol...
#    Component angle differs by 118258.066111 kcal/mol...
#    Component bond differs by 8058.04739218 kcal/mol...
# Molecule 27 has energy difference of 193744.378554 kcal/mol; out of tolerance.
#    Component nb differs by 7.50093700441 kcal/mol...
#    Component torsion differs by 1064.48090745 kcal/mol...
#    Component angle differs by 183554.394664 kcal/mol...
#    Component bond differs by 9133.00391961 kcal/mol...
# Molecule 29 has energy difference of 100099.888559 kcal/mol; out of tolerance.
#    Component nb differs by 11.0080875893 kcal/mol...
#    Component torsion differs by 4565.33762143 kcal/mol...
#    Component angle differs by 88480.7985381 kcal/mol...
#    Component bond differs by 7064.76048725 kcal/mol...
# Molecule 31 has energy difference of 76638.7460174 kcal/mol; out of tolerance.
#    Component nb differs by 5.76772054446 kcal/mol...
#    Component torsion differs by 2577.45380731 kcal/mol...
#    Component angle differs by 69040.511976 kcal/mol...
#    Component bond differs by 5026.5479546 kcal/mol...
# Molecule 36 has energy difference of 184116.187745 kcal/mol; out of tolerance.
#    Component nb differs by 104.934227004 kcal/mol...
#    Component torsion differs by 2890.93073426 kcal/mol...
#    Component angle differs by 168127.854047 kcal/mol...
#    Component bond differs by 13202.3371905 kcal/mol...
# Molecule 38 has energy difference of 135349.677375 kcal/mol; out of tolerance.
#    Component nb differs by 26.5551160527 kcal/mol...
#    Component torsion differs by 3535.01433883 kcal/mol...
#    Component angle differs by 122965.695268 kcal/mol...
#    Component bond differs by 8875.52288465 kcal/mol...
# Molecule 39 has energy difference of 131283.279869 kcal/mol; out of tolerance.
#    Component nb differs by 13.6903876823 kcal/mol...
#    Component torsion differs by 2697.77536434 kcal/mol...
#    Component angle differs by 120554.622216 kcal/mol...
#    Component bond differs by 8044.57267629 kcal/mol...
# Molecule 40 has energy difference of 142653.981613 kcal/mol; out of tolerance.
#    Component nb differs by 5.81571629305 kcal/mol...
#    Component torsion differs by 2457.43038986 kcal/mol...
#    Component angle differs by 134150.005266 kcal/mol...
#    Component bond differs by 6052.36167422 kcal/mol...
# Molecule 41 has energy difference of 95557.0774967 kcal/mol; out of tolerance.
#    Component nb differs by 6.31862953465 kcal/mol...
#    Component torsion differs by 1332.54599868 kcal/mol...
#    Component angle differs by 87945.9145806 kcal/mol...
#    Component bond differs by 6284.93554691 kcal/mol...
# Molecule 43 has energy difference of 121968.89906 kcal/mol; out of tolerance.
#    Component nb differs by 115.158489736 kcal/mol...
#    Component torsion differs by 1489.99163583 kcal/mol...
#    Component angle differs by 115748.226293 kcal/mol...
#    Component bond differs by 4845.83962136 kcal/mol...
# Molecule 46 has energy difference of 185032.517788 kcal/mol; out of tolerance.
#    Component nb differs by 48.4193736853 kcal/mol...
#    Component torsion differs by 868.279105096 kcal/mol...
#    Component angle differs by 173225.206312 kcal/mol...
#    Component bond differs by 10987.4517445 kcal/mol...
# Molecule 47 has energy difference of 141253.384312 kcal/mol; out of tolerance.
#    Component torsion differs by 6943.46444163 kcal/mol...
#    Component angle differs by 125696.342416 kcal/mol...
#    Component bond differs by 8614.76298834 kcal/mol...
# Molecule 48 has energy difference of 183873.074106 kcal/mol; out of tolerance.
#    Component nb differs by 30.0403120893 kcal/mol...
#    Component torsion differs by 2881.21490249 kcal/mol...
#    Component angle differs by 169124.107696 kcal/mol...
#    Component bond differs by 11897.7918201 kcal/mol...
# Molecule 49 has energy difference of 98912.1072672 kcal/mol; out of tolerance.
#    Component nb differs by 28.9539309741 kcal/mol...
#    Component torsion differs by 4893.04628197 kcal/mol...
#    Component angle differs by 87446.6179329 kcal/mol...
#    Component bond differs by 6601.39698322 kcal/mol...
# Molecule 50 has energy difference of 100773.373425 kcal/mol; out of tolerance.
#    Component torsion differs by 3421.719793 kcal/mol...
#    Component angle differs by 92073.8681473 kcal/mol...
#    Component bond differs by 5281.74960538 kcal/mol...
# Molecule 51 has energy difference of 132577.393841 kcal/mol; out of tolerance.
#    Component nb differs by 30.0481605023 kcal/mol...
#    Component torsion differs by 3035.80079878 kcal/mol...
#    Component angle differs by 120416.131878 kcal/mol...
#    Component bond differs by 9155.50932442 kcal/mol...
# Molecule 53 has energy difference of 189702.932297 kcal/mol; out of tolerance.
#    Component nb differs by 20.5381662333 kcal/mol...
#    Component torsion differs by 4621.70040996 kcal/mol...
#    Component angle differs by 172876.791821 kcal/mol...
#    Component bond differs by 12224.978232 kcal/mol...
# Molecule 54 has energy difference of 75600.4221989 kcal/mol; out of tolerance.
#    Component torsion differs by 2694.54069202 kcal/mol...
#    Component angle differs by 67959.8591176 kcal/mol...
#    Component bond differs by 4949.14848416 kcal/mol...
# Molecule 55 has energy difference of 131458.509401 kcal/mol; out of tolerance.
#    Component nb differs by 17.346696579 kcal/mol...
#    Component torsion differs by 3086.2374208 kcal/mol...
#    Component angle differs by 119974.286027 kcal/mol...
#    Component bond differs by 8415.33265023 kcal/mol...
# Molecule 58 has energy difference of 156109.837883 kcal/mol; out of tolerance.
#    Component torsion differs by 5876.03895494 kcal/mol...
#    Component angle differs by 140859.561972 kcal/mol...
#    Component bond differs by 9375.39414394 kcal/mol...
# Molecule 59 has energy difference of 124964.311948 kcal/mol; out of tolerance.
#    Component nb differs by 7.13832088291 kcal/mol...
#    Component torsion differs by 6548.45021758 kcal/mol...
#    Component angle differs by 111513.860219 kcal/mol...
#    Component bond differs by 6909.13983176 kcal/mol...
# Molecule 61 has energy difference of 63513.5707019 kcal/mol; out of tolerance.
#    Component nb differs by 4.34822833308 kcal/mol...
#    Component torsion differs by 1528.729229 kcal/mol...
#    Component angle differs by 58595.9898859 kcal/mol...
#    Component bond differs by 3393.19981532 kcal/mol...
# Molecule 62 has energy difference of 154882.154025 kcal/mol; out of tolerance.
#    Component nb differs by 5.97949622178 kcal/mol...
#    Component torsion differs by 5848.41567843 kcal/mol...
#    Component angle differs by 139588.824756 kcal/mol...
#    Component bond differs by 9450.893087 kcal/mol...
# Molecule 63 has energy difference of 160922.357158 kcal/mol; out of tolerance.
#    Component nb differs by 75.1510887298 kcal/mol...
#    Component torsion differs by 5741.31537416 kcal/mol...
#    Component angle differs by 146083.242329 kcal/mol...
#    Component bond differs by 9172.95054335 kcal/mol...
# Molecule 64 has energy difference of 131100.108715 kcal/mol; out of tolerance.
#    Component nb differs by 7.47619909534 kcal/mol...
#    Component torsion differs by 3499.96781054 kcal/mol...
#    Component angle differs by 121169.6902 kcal/mol...
#    Component bond differs by 6437.92690393 kcal/mol...
# Molecule 66 has energy difference of 29435.7738782 kcal/mol; out of tolerance.
#    Component nb differs by 7.6803438904 kcal/mol...
#    Component torsion differs by 1799.94849617 kcal/mol...
#    Component angle differs by 26368.020446 kcal/mol...
#    Component bond differs by 1275.48527998 kcal/mol...
# Molecule 67 has energy difference of 96962.3568711 kcal/mol; out of tolerance.
#    Component nb differs by 5.45576142734 kcal/mol...
#    Component torsion differs by 6027.90865262 kcal/mol...
#    Component angle differs by 85100.6393956 kcal/mol...
#    Component bond differs by 5839.26458439 kcal/mol...
# Molecule 68 has energy difference of 90935.058906 kcal/mol; out of tolerance.
#    Component nb differs by 7.26581535114 kcal/mol...
#    Component torsion differs by 3747.23685698 kcal/mol...
#    Component angle differs by 81214.1130461 kcal/mol...
#    Component bond differs by 5980.97481827 kcal/mol...
# Molecule 73 has energy difference of 138712.030948 kcal/mol; out of tolerance.
#    Component nb differs by 44.8716580429 kcal/mol...
#    Component torsion differs by 2822.82486591 kcal/mol...
#    Component angle differs by 128062.619416 kcal/mol...
#    Component bond differs by 7871.45832435 kcal/mol...
# Molecule 77 has energy difference of 89448.6676222 kcal/mol; out of tolerance.
#    Component nb differs by 9.20530636514 kcal/mol...
#    Component torsion differs by 3042.30172095 kcal/mol...
#    Component angle differs by 81764.9794579 kcal/mol...
#    Component bond differs by 4650.59174969 kcal/mol...
# Molecule 78 has energy difference of 111453.494651 kcal/mol; out of tolerance.
#    Component torsion differs by 3570.92852347 kcal/mol...
#    Component angle differs by 101443.32223 kcal/mol...
#    Component bond differs by 6442.9446802 kcal/mol...
# Molecule 79 has energy difference of 92001.030362 kcal/mol; out of tolerance.
#    Component nb differs by 4.61695196545 kcal/mol...
#    Component torsion differs by 2283.9674973 kcal/mol...
#    Component angle differs by 83484.4586075 kcal/mol...
#    Component bond differs by 6237.22120908 kcal/mol...
# Molecule 80 has energy difference of 141865.443239 kcal/mol; out of tolerance.
#    Component nb differs by 9.47153701948 kcal/mol...
#    Component torsion differs by 2183.44618697 kcal/mol...
#    Component angle differs by 131908.700176 kcal/mol...
#    Component bond differs by 7782.76841292 kcal/mol...
# Molecule 81 has energy difference of 144777.247199 kcal/mol; out of tolerance.
#    Component nb differs by 9.07068159334 kcal/mol...
#    Component torsion differs by 4566.38540531 kcal/mol...
#    Component angle differs by 131420.575419 kcal/mol...
#    Component bond differs by 8799.35705598 kcal/mol...
# Molecule 84 has energy difference of 170536.013442 kcal/mol; out of tolerance.
#    Component nb differs by 44.0654491436 kcal/mol...
#    Component torsion differs by 3728.29547334 kcal/mol...
#    Component angle differs by 155324.995335 kcal/mol...
#    Component bond differs by 11526.7880822 kcal/mol...
# Molecule 85 has energy difference of 99577.1033526 kcal/mol; out of tolerance.
#    Component nb differs by 22.6748087141 kcal/mol...
#    Component torsion differs by 1079.56260872 kcal/mol...
#    Component angle differs by 91704.2888189 kcal/mol...
#    Component bond differs by 6815.92673363 kcal/mol...
# Molecule 86 has energy difference of 104655.339327 kcal/mol; out of tolerance.
#    Component torsion differs by 3054.03763324 kcal/mol...
#    Component angle differs by 94425.8388283 kcal/mol...
#    Component bond differs by 7172.61484061 kcal/mol...
# Molecule 91 has energy difference of 66481.2022435 kcal/mol; out of tolerance.
#    Component torsion differs by 3587.99918287 kcal/mol...
#    Component angle differs by 59847.2174951 kcal/mol...
#    Component bond differs by 3048.54494716 kcal/mol...
# Molecule 92 has energy difference of 143410.77599 kcal/mol; out of tolerance.
#    Component nb differs by 33.4283309269 kcal/mol...
#    Component torsion differs by 4673.10775508 kcal/mol...
#    Component angle differs by 129406.41036 kcal/mol...
#    Component bond differs by 9364.68620579 kcal/mol...
# Molecule 94 has energy difference of 111007.948236 kcal/mol; out of tolerance.
#    Component nb differs by 17.1691442068 kcal/mol...
#    Component torsion differs by 2144.04470865 kcal/mol...
#    Component angle differs by 102267.100625 kcal/mol...
#    Component bond differs by 6613.97204722 kcal/mol...
# Molecule 96 has energy difference of 149628.611047 kcal/mol; out of tolerance.
#    Component nb differs by 90.4783433998 kcal/mol...
#    Component torsion differs by 2555.50076593 kcal/mol...
#    Component angle differs by 137394.650438 kcal/mol...
#    Component bond differs by 9768.93818683 kcal/mol...
# Molecule 100 has energy difference of 94275.8049765 kcal/mol; out of tolerance.
#    Component nb differs by 264.065063079 kcal/mol...
#    Component torsion differs by 3956.44035221 kcal/mol...
#    Component angle differs by 84645.5504653 kcal/mol...
#    Component bond differs by 5937.87922212 kcal/mol...
# Molecule 102 has energy difference of 161772.370261 kcal/mol; out of tolerance.
#    Component torsion differs by 6408.6551755 kcal/mol...
#    Component angle differs by 145672.450391 kcal/mol...
#    Component bond differs by 9694.43781694 kcal/mol...
# Molecule 103 has energy difference of 69945.8470338 kcal/mol; out of tolerance.
#    Component nb differs by 5.81702424874 kcal/mol...
#    Component torsion differs by 4248.5434322 kcal/mol...
#    Component angle differs by 61189.9623335 kcal/mol...
#    Component bond differs by 4513.15829232 kcal/mol...
# Molecule 104 has energy difference of 74322.2481079 kcal/mol; out of tolerance.
#    Component nb differs by 13.1822474038 kcal/mol...
#    Component torsion differs by 1232.04400411 kcal/mol...
#    Component angle differs by 67930.6769541 kcal/mol...
#    Component bond differs by 5172.70939711 kcal/mol...
# Molecule 105 has energy difference of 123058.095475 kcal/mol; out of tolerance.
#    Component torsion differs by 3668.91783072 kcal/mol...
#    Component angle differs by 113068.845052 kcal/mol...
#    Component bond differs by 6321.80210978 kcal/mol...
# Molecule 106 has energy difference of 137842.909564 kcal/mol; out of tolerance.
#    Component nb differs by 11.1162509313 kcal/mol...
#    Component torsion differs by 2670.95520731 kcal/mol...
#    Component angle differs by 125649.428967 kcal/mol...
#    Component bond differs by 9533.64163994 kcal/mol...
# Molecule 107 has energy difference of 159467.259249 kcal/mol; out of tolerance.
#    Component nb differs by 12.831688869 kcal/mol...
#    Component torsion differs by 4141.62781176 kcal/mol...
#    Component angle differs by 147268.855466 kcal/mol...
#    Component bond differs by 8069.60766087 kcal/mol...
# Molecule 108 has energy difference of 88070.647656 kcal/mol; out of tolerance.
#    Component nb differs by 6.07073733777 kcal/mol...
#    Component torsion differs by 6321.69067889 kcal/mol...
#    Component angle differs by 75635.7882388 kcal/mol...
#    Component bond differs by 6119.23947566 kcal/mol...
# Molecule 110 has energy difference of 168407.077717 kcal/mol; out of tolerance.
#    Component nb differs by 9.97755184168 kcal/mol...
#    Component torsion differs by 3005.18321629 kcal/mol...
#    Component angle differs by 156489.995234 kcal/mol...
#    Component bond differs by 8921.87681879 kcal/mol...
# Molecule 111 has energy difference of 128649.927711 kcal/mol; out of tolerance.
#    Component nb differs by 4.46924798544 kcal/mol...
#    Component torsion differs by 5097.14184343 kcal/mol...
#    Component angle differs by 116457.161538 kcal/mol...
#    Component bond differs by 7100.09357753 kcal/mol...
# Molecule 112 has energy difference of 90560.4864908 kcal/mol; out of tolerance.
#    Component nb differs by 5.71382649549 kcal/mol...
#    Component torsion differs by 821.748395 kcal/mol...
#    Component angle differs by 85529.5962057 kcal/mol...
#    Component bond differs by 4214.85571666 kcal/mol...
# Molecule 118 has energy difference of 68358.9128853 kcal/mol; out of tolerance.
#    Component torsion differs by 1184.49258337 kcal/mol...
#    Component angle differs by 62510.1720656 kcal/mol...
#    Component bond differs by 4666.79984409 kcal/mol...
# Molecule 120 has energy difference of 124282.935724 kcal/mol; out of tolerance.
#    Component nb differs by 112.810055135 kcal/mol...
#    Component torsion differs by 6274.33267104 kcal/mol...
#    Component angle differs by 111560.515159 kcal/mol...
#    Component bond differs by 6560.89794893 kcal/mol...
# Molecule 122 has energy difference of 87421.1424889 kcal/mol; out of tolerance.
#    Component torsion differs by 6020.61975921 kcal/mol...
#    Component angle differs by 75436.6402588 kcal/mol...
#    Component bond differs by 5963.40966662 kcal/mol...
# Molecule 128 has energy difference of 127108.99515 kcal/mol; out of tolerance.
#    Component nb differs by 38.0438079545 kcal/mol...
#    Component torsion differs by 4377.1700807 kcal/mol...
#    Component angle differs by 115088.9643 kcal/mol...
#    Component bond differs by 7680.90457744 kcal/mol...
# Molecule 130 has energy difference of 89623.2712048 kcal/mol; out of tolerance.
#    Component nb differs by 10.9481506543 kcal/mol...
#    Component torsion differs by 4122.53912956 kcal/mol...
#    Component angle differs by 80390.8439317 kcal/mol...
#    Component bond differs by 5120.83629416 kcal/mol...
# Molecule 131 has energy difference of 109642.079474 kcal/mol; out of tolerance.
#    Component nb differs by 6.08140627764 kcal/mol...
#    Component torsion differs by 5265.09903621 kcal/mol...
#    Component angle differs by 95534.9529429 kcal/mol...
#    Component bond differs by 8848.10890088 kcal/mol...
# Molecule 133 has energy difference of 85273.9426502 kcal/mol; out of tolerance.
#    Component nb differs by 10.9875056286 kcal/mol...
#    Component torsion differs by 2273.19132089 kcal/mol...
#    Component angle differs by 77784.2707313 kcal/mol...
#    Component bond differs by 5227.46810366 kcal/mol...
# Molecule 135 has energy difference of 144835.415833 kcal/mol; out of tolerance.
#    Component nb differs by 105.712923545 kcal/mol...
#    Component torsion differs by 2643.04500206 kcal/mol...
#    Component angle differs by 133665.641742 kcal/mol...
#    Component bond differs by 8632.44201267 kcal/mol...
# Molecule 137 has energy difference of 60560.199331 kcal/mol; out of tolerance.
#    Component torsion differs by 1814.36076707 kcal/mol...
#    Component angle differs by 55620.850115 kcal/mol...
#    Component bond differs by 3128.36856255 kcal/mol...
# Molecule 138 has energy difference of 121072.955127 kcal/mol; out of tolerance.
#    Component nb differs by 28.9468626142 kcal/mol...
#    Component torsion differs by 3544.04006956 kcal/mol...
#    Component angle differs by 110184.26274 kcal/mol...
#    Component bond differs by 7373.5991795 kcal/mol...
# Molecule 140 has energy difference of 138080.000903 kcal/mol; out of tolerance.
#    Component nb differs by 26.8038963461 kcal/mol...
#    Component torsion differs by 1473.36393593 kcal/mol...
#    Component angle differs by 127817.907694 kcal/mol...
#    Component bond differs by 8815.53316978 kcal/mol...
# Molecule 141 has energy difference of 95690.6168242 kcal/mol; out of tolerance.
#    Component torsion differs by 2175.62421073 kcal/mol...
#    Component angle differs by 87729.2296933 kcal/mol...
#    Component bond differs by 5789.08272403 kcal/mol...
# Molecule 143 has energy difference of 95015.8281206 kcal/mol; out of tolerance.
#    Component nb differs by 8.24029135959 kcal/mol...
#    Component torsion differs by 1421.18612174 kcal/mol...
#    Component angle differs by 87684.4754013 kcal/mol...
#    Component bond differs by 5918.40688893 kcal/mol...
# Molecule 144 has energy difference of 61659.5869048 kcal/mol; out of tolerance.
#    Component nb differs by 29.0967219233 kcal/mol...
#    Component torsion differs by 4221.70429897 kcal/mol...
#    Component angle differs by 54438.8289126 kcal/mol...
#    Component bond differs by 3028.15041519 kcal/mol...
# Molecule 146 has energy difference of 66634.6973355 kcal/mol; out of tolerance.
#    Component torsion differs by 1093.71601329 kcal/mol...
#    Component angle differs by 60742.750842 kcal/mol...
#    Component bond differs by 4797.83053986 kcal/mol...
# Molecule 150 has energy difference of 68002.6456389 kcal/mol; out of tolerance.
#    Component torsion differs by 2432.60740182 kcal/mol...
#    Component angle differs by 61724.6159352 kcal/mol...
#    Component bond differs by 3844.30181769 kcal/mol...
# Molecule 155 has energy difference of 68589.7179323 kcal/mol; out of tolerance.
#    Component torsion differs by 349.049508583 kcal/mol...
#    Component angle differs by 64620.3607758 kcal/mol...
#    Component bond differs by 3622.05904573 kcal/mol...
# Molecule 157 has energy difference of 118400.84114 kcal/mol; out of tolerance.
#    Component nb differs by 44.8729183007 kcal/mol...
#    Component torsion differs by 5602.23328534 kcal/mol...
#    Component angle differs by 106187.053698 kcal/mol...
#    Component bond differs by 6656.42707416 kcal/mol...
# Molecule 159 has energy difference of 140216.886411 kcal/mol; out of tolerance.
#    Component torsion differs by 3885.86119065 kcal/mol...
#    Component angle differs by 127659.172432 kcal/mol...
#    Component bond differs by 8675.14518394 kcal/mol...
# Molecule 160 has energy difference of 192111.905662 kcal/mol; out of tolerance.
#    Component nb differs by 8.07147946337 kcal/mol...
#    Component torsion differs by 3567.48617091 kcal/mol...
#    Component angle differs by 177291.112082 kcal/mol...
#    Component bond differs by 11261.3788887 kcal/mol...
# Molecule 161 has energy difference of 86252.7506956 kcal/mol; out of tolerance.
#    Component torsion differs by 2217.77996176 kcal/mol...
#    Component angle differs by 80311.9945499 kcal/mol...
#    Component bond differs by 3726.77384758 kcal/mol...
# Molecule 164 has energy difference of 143216.050207 kcal/mol; out of tolerance.
#    Component nb differs by 11.5207403403 kcal/mol...
#    Component torsion differs by 4521.68185725 kcal/mol...
#    Component angle differs by 130458.505659 kcal/mol...
#    Component bond differs by 8247.38343105 kcal/mol...
# Molecule 165 has energy difference of 155165.052045 kcal/mol; out of tolerance.
#    Component nb differs by 25.8573945505 kcal/mol...
#    Component torsion differs by 9490.07274443 kcal/mol...
#    Component angle differs by 134663.953534 kcal/mol...
#    Component bond differs by 11036.8831609 kcal/mol...
# Molecule 167 has energy difference of 95757.3580866 kcal/mol; out of tolerance.
#    Component nb differs by 10.1186243325 kcal/mol...
#    Component torsion differs by 5600.31804418 kcal/mol...
#    Component angle differs by 83733.8190758 kcal/mol...
#    Component bond differs by 6433.33959089 kcal/mol...
# Molecule 170 has energy difference of 157945.774899 kcal/mol; out of tolerance.
#    Component nb differs by 321.946437602 kcal/mol...
#    Component torsion differs by 3230.64995145 kcal/mol...
#    Component angle differs by 144377.482859 kcal/mol...
#    Component bond differs by 10659.5885259 kcal/mol...
# Molecule 171 has energy difference of 177860.730722 kcal/mol; out of tolerance.
#    Component nb differs by 79.76347238 kcal/mol...
#    Component torsion differs by 3833.39329868 kcal/mol...
#    Component angle differs by 164677.222948 kcal/mol...
#    Component bond differs by 9429.87794833 kcal/mol...
# Molecule 173 has energy difference of 72347.1489582 kcal/mol; out of tolerance.
#    Component torsion differs by 4199.99932816 kcal/mol...
#    Component angle differs by 64672.4598687 kcal/mol...
#    Component bond differs by 3477.25533992 kcal/mol...
# Molecule 174 has energy difference of 154373.606245 kcal/mol; out of tolerance.
#    Component nb differs by 44.6405990636 kcal/mol...
#    Component torsion differs by 7486.26744268 kcal/mol...
#    Component angle differs by 138597.764107 kcal/mol...
#    Component bond differs by 8334.21529437 kcal/mol...
# Molecule 175 has energy difference of 97570.7739956 kcal/mol; out of tolerance.
#    Component nb differs by 5.77338314672 kcal/mol...
#    Component torsion differs by 2225.90933423 kcal/mol...
#    Component angle differs by 89571.5681102 kcal/mol...
#    Component bond differs by 5779.06993433 kcal/mol...
# Molecule 176 has energy difference of 69615.9104982 kcal/mol; out of tolerance.
#    Component torsion differs by 1458.02910962 kcal/mol...
#    Component angle differs by 63693.1081154 kcal/mol...
#    Component bond differs by 4464.66440578 kcal/mol...
# Molecule 177 has energy difference of 111691.088831 kcal/mol; out of tolerance.
#    Component nb differs by 8.15350512991 kcal/mol...
#    Component torsion differs by 4199.93789968 kcal/mol...
#    Component angle differs by 101844.467532 kcal/mol...
#    Component bond differs by 5654.83690459 kcal/mol...
# Molecule 179 has energy difference of 76863.9218687 kcal/mol; out of tolerance.
#    Component nb differs by 9.3980051775 kcal/mol...
#    Component torsion differs by 2875.83613415 kcal/mol...
#    Component angle differs by 69108.7037919 kcal/mol...
#    Component bond differs by 4888.77994777 kcal/mol...
# Molecule 182 has energy difference of 113953.574561 kcal/mol; out of tolerance.
#    Component nb differs by 11.7056558627 kcal/mol...
#    Component torsion differs by 1328.76220571 kcal/mol...
#    Component angle differs by 106885.958925 kcal/mol...
#    Component bond differs by 5750.55908575 kcal/mol...
# Molecule 183 has energy difference of 158716.886585 kcal/mol; out of tolerance.
#    Component nb differs by 65.5565917648 kcal/mol...
#    Component torsion differs by 3819.12426063 kcal/mol...
#    Component angle differs by 146337.553481 kcal/mol...
#    Component bond differs by 8625.7654352 kcal/mol...
# Molecule 184 has energy difference of 65392.5636328 kcal/mol; out of tolerance.
#    Component torsion differs by 3142.34932414 kcal/mol...
#    Component angle differs by 58303.8446944 kcal/mol...
#    Component bond differs by 3945.34513028 kcal/mol...
# Molecule 191 has energy difference of 130947.517264 kcal/mol; out of tolerance.
#    Component nb differs by 7.28316809824 kcal/mol...
#    Component torsion differs by 4718.48081394 kcal/mol...
#    Component angle differs by 116944.363557 kcal/mol...
#    Component bond differs by 9291.95606096 kcal/mol...
# Molecule 192 has energy difference of 141183.731669 kcal/mol; out of tolerance.
#    Component nb differs by 47.7986939616 kcal/mol...
#    Component torsion differs by 4540.05516523 kcal/mol...
#    Component angle differs by 129137.0931 kcal/mol...
#    Component bond differs by 7554.38209794 kcal/mol...
# Molecule 193 has energy difference of 147941.814541 kcal/mol; out of tolerance.
#    Component nb differs by 52.6103819951 kcal/mol...
#    Component torsion differs by 2915.50489001 kcal/mol...
#    Component angle differs by 137161.467279 kcal/mol...
#    Component bond differs by 7917.45275405 kcal/mol...
# Molecule 194 has energy difference of 32987.4950431 kcal/mol; out of tolerance.
#    Component torsion differs by 1799.9792179 kcal/mol...
#    Component angle differs by 28214.2978286 kcal/mol...
#    Component bond differs by 2972.95473539 kcal/mol...
# Molecule 195 has energy difference of 135441.529605 kcal/mol; out of tolerance.
#    Component nb differs by 31.1482878705 kcal/mol...
#    Component torsion differs by 2418.92727749 kcal/mol...
#    Component angle differs by 124584.039291 kcal/mol...
#    Component bond differs by 8469.71132432 kcal/mol...
# Molecule 197 has energy difference of 130460.067569 kcal/mol; out of tolerance.
#    Component nb differs by 7.93443617443 kcal/mol...
#    Component torsion differs by 4928.94924092 kcal/mol...
#    Component angle differs by 117875.713779 kcal/mol...
#    Component bond differs by 7663.33898466 kcal/mol...
# Molecule 199 has energy difference of 158616.095926 kcal/mol; out of tolerance.
#    Component nb differs by 15.3520682078 kcal/mol...
#    Component torsion differs by 1306.58765998 kcal/mol...
#    Component angle differs by 149346.379605 kcal/mol...
#    Component bond differs by 7978.4807291 kcal/mol...
# Molecule 204 has energy difference of 102976.598206 kcal/mol; out of tolerance.
#    Component nb differs by 12.2875925411 kcal/mol...
#    Component torsion differs by 3128.9024103 kcal/mol...
#    Component angle differs by 94296.4778592 kcal/mol...
#    Component bond differs by 5563.50552932 kcal/mol...
# Molecule 205 has energy difference of 78286.1756333 kcal/mol; out of tolerance.
#    Component torsion differs by 4329.97654098 kcal/mol...
#    Component angle differs by 69109.1642698 kcal/mol...
#    Component bond differs by 4845.96640716 kcal/mol...
# Molecule 206 has energy difference of 179298.542929 kcal/mol; out of tolerance.
#    Component nb differs by 32.4907180674 kcal/mol...
#    Component torsion differs by 2847.64236056 kcal/mol...
#    Component angle differs by 167544.421602 kcal/mol...
#    Component bond differs by 8938.96968438 kcal/mol...
# Molecule 207 has energy difference of 162851.04433 kcal/mol; out of tolerance.
#    Component nb differs by 40.5688449917 kcal/mol...
#    Component torsion differs by 2516.66394054 kcal/mol...
#    Component angle differs by 149970.780762 kcal/mol...
#    Component bond differs by 10404.1684724 kcal/mol...
# Molecule 208 has energy difference of 141744.08187 kcal/mol; out of tolerance.
#    Component nb differs by 4.06643118439 kcal/mol...
#    Component torsion differs by 169.966709935 kcal/mol...
#    Component angle differs by 134034.538842 kcal/mol...
#    Component bond differs by 7543.64274994 kcal/mol...
# Molecule 212 has energy difference of 115416.095493 kcal/mol; out of tolerance.
#    Component nb differs by 9.01942319062 kcal/mol...
#    Component torsion differs by 3939.73794209 kcal/mol...
#    Component angle differs by 103421.342998 kcal/mol...
#    Component bond differs by 8064.03397656 kcal/mol...
# Molecule 214 has energy difference of 88472.7519749 kcal/mol; out of tolerance.
#    Component torsion differs by 2849.35728274 kcal/mol...
#    Component angle differs by 80489.2254449 kcal/mol...
#    Component bond differs by 5137.30306908 kcal/mol...
# Molecule 215 has energy difference of 125655.547072 kcal/mol; out of tolerance.
#    Component nb differs by 30.0180571529 kcal/mol...
#    Component torsion differs by 3073.24564193 kcal/mol...
#    Component angle differs by 116203.900721 kcal/mol...
#    Component bond differs by 6408.41876593 kcal/mol...
# Molecule 216 has energy difference of 97189.4318406 kcal/mol; out of tolerance.
#    Component nb differs by 21.6371296634 kcal/mol...
#    Component torsion differs by 3219.19333331 kcal/mol...
#    Component angle differs by 87723.0765277 kcal/mol...
#    Component bond differs by 6268.79910919 kcal/mol...
# Molecule 218 has energy difference of 94037.5721543 kcal/mol; out of tolerance.
#    Component nb differs by 5.47028924006 kcal/mol...
#    Component torsion differs by 3243.45535165 kcal/mol...
#    Component angle differs by 84884.2323891 kcal/mol...
#    Component bond differs by 5915.35470282 kcal/mol...
# Molecule 219 has energy difference of 128137.446303 kcal/mol; out of tolerance.
#    Component nb differs by 22.953756018 kcal/mol...
#    Component torsion differs by 2649.64369046 kcal/mol...
#    Component angle differs by 118771.20619 kcal/mol...
#    Component bond differs by 6739.55017809 kcal/mol...
# Molecule 220 has energy difference of 96174.3975818 kcal/mol; out of tolerance.
#    Component torsion differs by 3048.95262484 kcal/mol...
#    Component angle differs by 86875.8252263 kcal/mol...
#    Component bond differs by 6250.0197268 kcal/mol...
# Molecule 221 has energy difference of 98123.3662823 kcal/mol; out of tolerance.
#    Component torsion differs by 3434.063522 kcal/mol...
#    Component angle differs by 89176.261704 kcal/mol...
#    Component bond differs by 5516.18435056 kcal/mol...
# Molecule 222 has energy difference of 125805.269693 kcal/mol; out of tolerance.
#    Component nb differs by 26.6940843474 kcal/mol...
#    Component torsion differs by 3135.2858285 kcal/mol...
#    Component angle differs by 114012.823877 kcal/mol...
#    Component bond differs by 8683.85407161 kcal/mol...
# Molecule 225 has energy difference of 68714.0702416 kcal/mol; out of tolerance.
#    Component torsion differs by 5213.05007546 kcal/mol...
#    Component angle differs by 59127.2133415 kcal/mol...
#    Component bond differs by 4374.82112141 kcal/mol...
# Molecule 227 has energy difference of 89211.962636 kcal/mol; out of tolerance.
#    Component nb differs by 52.2817628851 kcal/mol...
#    Component torsion differs by 2504.66058663 kcal/mol...
#    Component angle differs by 81119.0448727 kcal/mol...
#    Component bond differs by 5640.53893962 kcal/mol...
# Molecule 229 has energy difference of 141239.211966 kcal/mol; out of tolerance.
#    Component nb differs by 23.1721728796 kcal/mol...
#    Component torsion differs by 1842.90081298 kcal/mol...
#    Component angle differs by 129222.782069 kcal/mol...
#    Component bond differs by 10196.7012562 kcal/mol...
# Molecule 231 has energy difference of 132148.736668 kcal/mol; out of tolerance.
#    Component nb differs by 11.1751832955 kcal/mol...
#    Component torsion differs by 2839.3948368 kcal/mol...
#    Component angle differs by 122609.724385 kcal/mol...
#    Component bond differs by 6710.79262901 kcal/mol...
# Molecule 234 has energy difference of 152954.335187 kcal/mol; out of tolerance.
#    Component nb differs by 15.8564674581 kcal/mol...
#    Component torsion differs by 4167.56334746 kcal/mol...
#    Component angle differs by 141060.572365 kcal/mol...
#    Component bond differs by 7742.0559416 kcal/mol...
# Molecule 238 has energy difference of 168441.372097 kcal/mol; out of tolerance.
#    Component nb differs by 111.261250284 kcal/mol...
#    Component torsion differs by 1682.04350702 kcal/mol...
#    Component angle differs by 156152.957416 kcal/mol...
#    Component bond differs by 10717.6324248 kcal/mol...
# Molecule 239 has energy difference of 98909.3547224 kcal/mol; out of tolerance.
#    Component torsion differs by 4623.43093579 kcal/mol...
#    Component angle differs by 89230.9159873 kcal/mol...
#    Component bond differs by 5056.33436191 kcal/mol...
# Molecule 241 has energy difference of 116123.837848 kcal/mol; out of tolerance.
#    Component nb differs by 9.54337055074 kcal/mol...
#    Component torsion differs by 3992.61100244 kcal/mol...
#    Component angle differs by 105306.709727 kcal/mol...
#    Component bond differs by 6834.06048923 kcal/mol...
# Molecule 242 has energy difference of 89049.7344621 kcal/mol; out of tolerance.
#    Component nb differs by 49.0328258565 kcal/mol...
#    Component torsion differs by 3678.21145527 kcal/mol...
#    Component angle differs by 78582.243756 kcal/mol...
#    Component bond differs by 6838.31207662 kcal/mol...
# Molecule 243 has energy difference of 155345.391065 kcal/mol; out of tolerance.
#    Component nb differs by 20.111321325 kcal/mol...
#    Component torsion differs by 2037.33546045 kcal/mol...
#    Component angle differs by 145051.271811 kcal/mol...
#    Component bond differs by 8276.89511467 kcal/mol...
# Molecule 244 has energy difference of 62976.8710121 kcal/mol; out of tolerance.
#    Component torsion differs by 2637.47228511 kcal/mol...
#    Component angle differs by 56161.9784738 kcal/mol...
#    Component bond differs by 4178.84842192 kcal/mol...
# Molecule 247 has energy difference of 117961.275602 kcal/mol; out of tolerance.
#    Component nb differs by 9.59807707986 kcal/mol...
#    Component torsion differs by 3765.25128414 kcal/mol...
#    Component angle differs by 107369.692779 kcal/mol...
#    Component bond differs by 6835.9296155 kcal/mol...
# Molecule 248 has energy difference of 77903.7581711 kcal/mol; out of tolerance.
#    Component nb differs by 6.3663770855 kcal/mol...
#    Component torsion differs by 4034.29322957 kcal/mol...
#    Component angle differs by 68338.9374603 kcal/mol...
#    Component bond differs by 5536.89385825 kcal/mol...
# Molecule 249 has energy difference of 92044.4141748 kcal/mol; out of tolerance.
#    Component nb differs by 337.133981714 kcal/mol...
#    Component torsion differs by 3221.96349407 kcal/mol...
#    Component angle differs by 83453.7951052 kcal/mol...
#    Component bond differs by 5705.78955723 kcal/mol...
# Molecule 250 has energy difference of 122362.975046 kcal/mol; out of tolerance.
#    Component nb differs by 8.51213740494 kcal/mol...
#    Component torsion differs by 3390.13932097 kcal/mol...
#    Component angle differs by 113106.880327 kcal/mol...
#    Component bond differs by 5874.4675348 kcal/mol...
# Molecule 251 has energy difference of 81077.4031852 kcal/mol; out of tolerance.
#    Component nb differs by 6.74414865745 kcal/mol...
#    Component torsion differs by 4021.66515599 kcal/mol...
#    Component angle differs by 71866.3553903 kcal/mol...
#    Component bond differs by 5196.12678756 kcal/mol...
# Molecule 253 has energy difference of 165403.18663 kcal/mol; out of tolerance.
#    Component nb differs by 46.8384773381 kcal/mol...
#    Component torsion differs by 4864.5080648 kcal/mol...
#    Component angle differs by 151769.399434 kcal/mol...
#    Component bond differs by 8816.11760884 kcal/mol...
# Molecule 256 has energy difference of 43670.4659827 kcal/mol; out of tolerance.
#    Component torsion differs by 1492.76159318 kcal/mol...
#    Component angle differs by 38733.50652 kcal/mol...
#    Component bond differs by 3446.9721442 kcal/mol...
# Molecule 258 has energy difference of 147110.980336 kcal/mol; out of tolerance.
#    Component nb differs by 13.7902801105 kcal/mol...
#    Component torsion differs by 3355.66123663 kcal/mol...
#    Component angle differs by 135186.770326 kcal/mol...
#    Component bond differs by 8582.33905373 kcal/mol...
# Molecule 260 has energy difference of 93236.4452887 kcal/mol; out of tolerance.
#    Component nb differs by 16.4033316865 kcal/mol...
#    Component torsion differs by 4854.3099434 kcal/mol...
#    Component angle differs by 82706.8960007 kcal/mol...
#    Component bond differs by 5691.64267631 kcal/mol...
# Molecule 262 has energy difference of 116728.567478 kcal/mol; out of tolerance.
#    Component nb differs by 12.5154271103 kcal/mol...
#    Component torsion differs by 4265.56008563 kcal/mol...
#    Component angle differs by 105726.7447 kcal/mol...
#    Component bond differs by 6748.77811989 kcal/mol...
# Molecule 263 has energy difference of 135334.657391 kcal/mol; out of tolerance.
#    Component nb differs by 16.3432647272 kcal/mol...
#    Component torsion differs by 5958.20678941 kcal/mol...
#    Component angle differs by 120557.083771 kcal/mol...
#    Component bond differs by 8835.71009529 kcal/mol...
# Molecule 265 has energy difference of 126829.713863 kcal/mol; out of tolerance.
#    Component nb differs by 33.920489847 kcal/mol...
#    Component torsion differs by 2530.7946295 kcal/mol...
#    Component angle differs by 116608.493507 kcal/mol...
#    Component bond differs by 7724.34621678 kcal/mol...
# Molecule 268 has energy difference of 116205.223411 kcal/mol; out of tolerance.
#    Component nb differs by 40.5966350448 kcal/mol...
#    Component torsion differs by 2634.23811064 kcal/mol...
#    Component angle differs by 106164.28754 kcal/mol...
#    Component bond differs by 7447.29439572 kcal/mol...
# Molecule 269 has energy difference of 151367.822852 kcal/mol; out of tolerance.
#    Component nb differs by 34.1748273218 kcal/mol...
#    Component torsion differs by 5998.06854735 kcal/mol...
#    Component angle differs by 135991.0935 kcal/mol...
#    Component bond differs by 9412.83563253 kcal/mol...
# Molecule 270 has energy difference of 78716.2739757 kcal/mol; out of tolerance.
#    Component nb differs by 6.48303247215 kcal/mol...
#    Component torsion differs by 3984.9510915 kcal/mol...
#    Component angle differs by 69963.5077272 kcal/mol...
#    Component bond differs by 4774.29818944 kcal/mol...
# Molecule 271 has energy difference of 151281.968581 kcal/mol; out of tolerance.
#    Component nb differs by 23.9102552904 kcal/mol...
#    Component torsion differs by 4293.62329945 kcal/mol...
#    Component angle differs by 138860.044512 kcal/mol...
#    Component bond differs by 8152.21102408 kcal/mol...
# Molecule 272 has energy difference of 138659.529305 kcal/mol; out of tolerance.
#    Component nb differs by 42.2904116657 kcal/mol...
#    Component torsion differs by 2667.79014438 kcal/mol...
#    Component angle differs by 128434.021343 kcal/mol...
#    Component bond differs by 7600.00822954 kcal/mol...
# Molecule 273 has energy difference of 77800.4683503 kcal/mol; out of tolerance.
#    Component torsion differs by 2721.71788855 kcal/mol...
#    Component angle differs by 70570.3898738 kcal/mol...
#    Component bond differs by 4511.66300351 kcal/mol...
# Molecule 274 has energy difference of 139515.070837 kcal/mol; out of tolerance.
#    Component nb differs by 18.0232008282 kcal/mol...
#    Component torsion differs by 4210.98328698 kcal/mol...
#    Component angle differs by 127332.446489 kcal/mol...
#    Component bond differs by 7989.6642619 kcal/mol...
# Molecule 278 has energy difference of 129076.29175 kcal/mol; out of tolerance.
#    Component nb differs by 16.0161140564 kcal/mol...
#    Component torsion differs by 3534.23558975 kcal/mol...
#    Component angle differs by 117814.959268 kcal/mol...
#    Component bond differs by 7743.11300677 kcal/mol...
# Molecule 279 has energy difference of 132848.336554 kcal/mol; out of tolerance.
#    Component nb differs by 24.6380546454 kcal/mol...
#    Component torsion differs by 1081.75960165 kcal/mol...
#    Component angle differs by 123043.63189 kcal/mol...
#    Component bond differs by 8747.58311676 kcal/mol...
# Molecule 280 has energy difference of 171311.504392 kcal/mol; out of tolerance.
#    Component nb differs by 11.2377890025 kcal/mol...
#    Component torsion differs by 5368.06612633 kcal/mol...
#    Component angle differs by 156399.786566 kcal/mol...
#    Component bond differs by 9554.88948787 kcal/mol...
# Molecule 281 has energy difference of 144328.444671 kcal/mol; out of tolerance.
#    Component nb differs by 50.1132569859 kcal/mol...
#    Component torsion differs by 271.596695925 kcal/mol...
#    Component angle differs by 136949.933149 kcal/mol...
#    Component bond differs by 7157.02808255 kcal/mol...
# Molecule 286 has energy difference of 151755.840322 kcal/mol; out of tolerance.
#    Component nb differs by 10.4815943884 kcal/mol...
#    Component torsion differs by 3790.60482783 kcal/mol...
#    Component angle differs by 138023.777628 kcal/mol...
#    Component bond differs by 9951.93945996 kcal/mol...
# Molecule 287 has energy difference of 99238.8738404 kcal/mol; out of tolerance.
#    Component torsion differs by 4970.82208073 kcal/mol...
#    Component angle differs by 87217.3215063 kcal/mol...
#    Component bond differs by 7049.7060269 kcal/mol...
# Molecule 288 has energy difference of 130231.816838 kcal/mol; out of tolerance.
#    Component nb differs by 17.4698488822 kcal/mol...
#    Component torsion differs by 3154.34789803 kcal/mol...
#    Component angle differs by 120637.199972 kcal/mol...
#    Component bond differs by 6457.73881664 kcal/mol...
# Molecule 289 has energy difference of 171159.047021 kcal/mol; out of tolerance.
#    Component nb differs by 25.3941436145 kcal/mol...
#    Component torsion differs by 6133.06134742 kcal/mol...
#    Component angle differs by 154193.052201 kcal/mol...
#    Component bond differs by 10858.3276155 kcal/mol...
# Molecule 291 has energy difference of 97954.464825 kcal/mol; out of tolerance.
#    Component nb differs by 10.7861909654 kcal/mol...
#    Component torsion differs by 4596.375359 kcal/mol...
#    Component angle differs by 87896.3260471 kcal/mol...
#    Component bond differs by 5472.54960989 kcal/mol...
# Molecule 294 has energy difference of 110123.318442 kcal/mol; out of tolerance.
#    Component nb differs by 58.639741341 kcal/mol...
#    Component torsion differs by 1701.58832101 kcal/mol...
#    Component angle differs by 101126.477994 kcal/mol...
#    Component bond differs by 7353.89186893 kcal/mol...
# Molecule 295 has energy difference of 101517.810874 kcal/mol; out of tolerance.
#    Component nb differs by 10.2514649749 kcal/mol...
#    Component torsion differs by 3359.52065074 kcal/mol...
#    Component angle differs by 93452.1526332 kcal/mol...
#    Component bond differs by 4716.3890549 kcal/mol...
# Molecule 296 has energy difference of 88442.1498871 kcal/mol; out of tolerance.
#    Component nb differs by 11.5396978528 kcal/mol...
#    Component torsion differs by 2597.51750838 kcal/mol...
#    Component angle differs by 79115.7052557 kcal/mol...
#    Component bond differs by 6740.46682087 kcal/mol...
# Molecule 297 has energy difference of 74832.3385612 kcal/mol; out of tolerance.
#    Component torsion differs by 3879.44770357 kcal/mol...
#    Component angle differs by 66331.143959 kcal/mol...
#    Component bond differs by 4621.88720902 kcal/mol...
# Molecule 298 has energy difference of 112502.425601 kcal/mol; out of tolerance.
#    Component nb differs by 9.66660627695 kcal/mol...
#    Component torsion differs by 4273.02014192 kcal/mol...
#    Component angle differs by 100075.63739 kcal/mol...
#    Component bond differs by 8163.43467463 kcal/mol...
# Molecule 299 has energy difference of 184658.21254 kcal/mol; out of tolerance.
#    Component nb differs by 30.1506867116 kcal/mol...
#    Component torsion differs by 1042.66335045 kcal/mol...
#    Component angle differs by 170870.02438 kcal/mol...
#    Component bond differs by 12775.6754959 kcal/mol...
# Molecule 304 has energy difference of 56149.3195124 kcal/mol; out of tolerance.
#    Component torsion differs by 92.2825181328 kcal/mol...
#    Component angle differs by 52592.8643847 kcal/mol...
#    Component bond differs by 3464.77734949 kcal/mol...
# Molecule 306 has energy difference of 103921.495826 kcal/mol; out of tolerance.
#    Component nb differs by 10.3813585507 kcal/mol...
#    Component torsion differs by 3032.50430366 kcal/mol...
#    Component angle differs by 95034.139288 kcal/mol...
#    Component bond differs by 5865.233593 kcal/mol...
# Molecule 310 has energy difference of 88121.914724 kcal/mol; out of tolerance.
#    Component torsion differs by 3099.9686602 kcal/mol...
#    Component angle differs by 79192.2530234 kcal/mol...
#    Component bond differs by 5830.70140697 kcal/mol...
# Molecule 311 has energy difference of 140058.129627 kcal/mol; out of tolerance.
#    Component nb differs by 11.0120475174 kcal/mol...
#    Component torsion differs by 1162.34045624 kcal/mol...
# ...
#    Component nb differs by 8.3527189115 kcal/mol...
#    Component torsion differs by 2045.53433045 kcal/mol...
#    Component angle differs by 84836.1389765 kcal/mol...
#    Component bond differs by 5659.77301576 kcal/mol...
# Molecule 7367 has energy difference of 103357.194388 kcal/mol; out of tolerance.
#    Component nb differs by 9.7586062812 kcal/mol...
#    Component torsion differs by 1216.00777512 kcal/mol...
#    Component angle differs by 96621.9275214 kcal/mol...
#    Component bond differs by 5529.01769812 kcal/mol...
# Molecule 7370 has energy difference of 116485.18642 kcal/mol; out of tolerance.
#    Component nb differs by 10.0297568156 kcal/mol...
#    Component torsion differs by 3871.00084232 kcal/mol...
#    Component angle differs by 106109.559055 kcal/mol...
#    Component bond differs by 6514.65627902 kcal/mol...
# Molecule 7373 has energy difference of 137021.615522 kcal/mol; out of tolerance.
#    Component nb differs by 5.01310917122 kcal/mol...
#    Component torsion differs by 5484.96597466 kcal/mol...
#    Component angle differs by 124387.218831 kcal/mol...
#    Component bond differs by 7154.44382593 kcal/mol...
# Molecule 7375 has energy difference of 86804.3794496 kcal/mol; out of tolerance.
#    Component torsion differs by 3498.23933647 kcal/mol...
#    Component angle differs by 76953.147636 kcal/mol...
#    Component bond differs by 6355.5117295 kcal/mol...
# Molecule 7376 has energy difference of 96089.6899321 kcal/mol; out of tolerance.
#    Component torsion differs by 3463.35054148 kcal/mol...
#    Component angle differs by 87400.566616 kcal/mol...
#    Component bond differs by 5228.86417482 kcal/mol...
# Molecule 7378 has energy difference of 74558.601513 kcal/mol; out of tolerance.
#    Component nb differs by 4.26480366496 kcal/mol...
#    Component torsion differs by 3321.72401116 kcal/mol...
#    Component angle differs by 67008.0349363 kcal/mol...
#    Component bond differs by 4233.10736925 kcal/mol...
# Molecule 7379 has energy difference of 163324.571538 kcal/mol; out of tolerance.
#    Component nb differs by 11.8554118946 kcal/mol...
#    Component torsion differs by 3843.39180605 kcal/mol...
#    Component angle differs by 151087.685147 kcal/mol...
#    Component bond differs by 8405.34999692 kcal/mol...
# Molecule 7380 has energy difference of 138367.645458 kcal/mol; out of tolerance.
#    Component nb differs by 16.5991385756 kcal/mol...
#    Component torsion differs by 2644.91906388 kcal/mol...
#    Component angle differs by 129418.090001 kcal/mol...
#    Component bond differs by 6321.23553138 kcal/mol...
# Molecule 7382 has energy difference of 177092.905244 kcal/mol; out of tolerance.
#    Component nb differs by 89.0840143844 kcal/mol...
#    Component torsion differs by 3241.13093743 kcal/mol...
#    Component angle differs by 162751.399476 kcal/mol...
#    Component bond differs by 11189.4588455 kcal/mol...
# Molecule 7385 has energy difference of 144481.63195 kcal/mol; out of tolerance.
#    Component nb differs by 21.1386645212 kcal/mol...
#    Component torsion differs by 2244.02354347 kcal/mol...
#    Component angle differs by 133100.016426 kcal/mol...
#    Component bond differs by 9158.73064488 kcal/mol...
# Molecule 7386 has energy difference of 105064.562706 kcal/mol; out of tolerance.
#    Component nb differs by 12.0791858646 kcal/mol...
#    Component torsion differs by 2736.98498061 kcal/mol...
#    Component angle differs by 95957.5762416 kcal/mol...
#    Component bond differs by 6382.08066925 kcal/mol...
# Molecule 7395 has energy difference of 84521.0669176 kcal/mol; out of tolerance.
#    Component nb differs by 8.11231494374 kcal/mol...
#    Component torsion differs by 2154.88158768 kcal/mol...
#    Component angle differs by 76370.9065585 kcal/mol...
#    Component bond differs by 6003.3910863 kcal/mol...
# Molecule 7396 has energy difference of 153390.885712 kcal/mol; out of tolerance.
#    Component nb differs by 20.87681213 kcal/mol...
#    Component torsion differs by 2501.66521191 kcal/mol...
#    Component angle differs by 140929.202023 kcal/mol...
#    Component bond differs by 9980.89529013 kcal/mol...
# Molecule 7399 has energy difference of 91858.6042009 kcal/mol; out of tolerance.
#    Component torsion differs by 1041.85165335 kcal/mol...
#    Component angle differs by 85425.9036973 kcal/mol...
#    Component bond differs by 5393.2934971 kcal/mol...
# Molecule 7403 has energy difference of 136775.223781 kcal/mol; out of tolerance.
#    Component nb differs by 35.6705306766 kcal/mol...
#    Component torsion differs by 3454.05570064 kcal/mol...
#    Component angle differs by 124176.644421 kcal/mol...
#    Component bond differs by 9180.19419028 kcal/mol...
# Molecule 7406 has energy difference of 113339.430537 kcal/mol; out of tolerance.
#    Component torsion differs by 2088.31670038 kcal/mol...
#    Component angle differs by 104889.39261 kcal/mol...
#    Component bond differs by 6363.2327814 kcal/mol...
# Molecule 7407 has energy difference of 147440.467838 kcal/mol; out of tolerance.
#    Component nb differs by 34.3208713926 kcal/mol...
#    Component torsion differs by 5113.81285862 kcal/mol...
#    Component angle differs by 131266.740897 kcal/mol...
#    Component bond differs by 11094.2349542 kcal/mol...
# Molecule 7410 has energy difference of 89851.5963038 kcal/mol; out of tolerance.
#    Component torsion differs by 2535.15008019 kcal/mol...
#    Component angle differs by 81310.4212423 kcal/mol...
#    Component bond differs by 6009.06292143 kcal/mol...
# Molecule 7414 has energy difference of 51375.2993959 kcal/mol; out of tolerance.
#    Component torsion differs by 740.782504493 kcal/mol...
#    Component angle differs by 47122.8409862 kcal/mol...
#    Component bond differs by 3512.0511131 kcal/mol...
# Molecule 7419 has energy difference of 124353.781067 kcal/mol; out of tolerance.
#    Component nb differs by 14.2069131726 kcal/mol...
#    Component torsion differs by 3060.16744889 kcal/mol...
#    Component angle differs by 114669.353989 kcal/mol...
#    Component bond differs by 6638.46654168 kcal/mol...
# Molecule 7420 has energy difference of 147721.718091 kcal/mol; out of tolerance.
#    Component nb differs by 32.4057450996 kcal/mol...
#    Component torsion differs by 2837.36487806 kcal/mol...
#    Component angle differs by 135937.590232 kcal/mol...
#    Component bond differs by 8979.16872585 kcal/mol...
# Molecule 7422 has energy difference of 113494.980041 kcal/mol; out of tolerance.
#    Component torsion differs by 2740.85979347 kcal/mol...
#    Component angle differs by 104093.317137 kcal/mol...
#    Component bond differs by 6661.73156839 kcal/mol...
# Molecule 7425 has energy difference of 169016.925847 kcal/mol; out of tolerance.
#    Component torsion differs by 6274.9265359 kcal/mol...
#    Component angle differs by 152838.46004 kcal/mol...
#    Component bond differs by 9906.33388989 kcal/mol...
# Molecule 7426 has energy difference of 39960.4395454 kcal/mol; out of tolerance.
#    Component torsion differs by 3599.98772513 kcal/mol...
#    Component angle differs by 33745.0269873 kcal/mol...
#    Component bond differs by 2614.88295451 kcal/mol...
# Molecule 7429 has energy difference of 89976.2103423 kcal/mol; out of tolerance.
#    Component nb differs by 4.35956447306 kcal/mol...
#    Component torsion differs by 2717.69636912 kcal/mol...
#    Component angle differs by 82610.2121694 kcal/mol...
#    Component bond differs by 4652.66136831 kcal/mol...
# Molecule 7434 has energy difference of 55978.9101571 kcal/mol; out of tolerance.
#    Component nb differs by 4.16464799767 kcal/mol...
#    Component torsion differs by 2399.82123303 kcal/mol...
#    Component angle differs by 50307.8104795 kcal/mol...
#    Component bond differs by 3275.44309266 kcal/mol...
# Molecule 7437 has energy difference of 134798.435851 kcal/mol; out of tolerance.
#    Component nb differs by 23.4709656341 kcal/mol...
#    Component torsion differs by 2050.69228762 kcal/mol...
#    Component angle differs by 125082.557399 kcal/mol...
#    Component bond differs by 7688.65713077 kcal/mol...
# Molecule 7440 has energy difference of 132079.632609 kcal/mol; out of tolerance.
#    Component nb differs by 14.4187042752 kcal/mol...
#    Component torsion differs by 2197.56809562 kcal/mol...
#    Component angle differs by 123757.386906 kcal/mol...
#    Component bond differs by 6139.09631165 kcal/mol...
# Molecule 7441 has energy difference of 120784.395658 kcal/mol; out of tolerance.
#    Component nb differs by 15.4515838923 kcal/mol...
#    Component torsion differs by 3727.12439792 kcal/mol...
#    Component angle differs by 109394.48321 kcal/mol...
#    Component bond differs by 7678.2396339 kcal/mol...
# Molecule 7442 has energy difference of 150187.099727 kcal/mol; out of tolerance.
#    Component nb differs by 24.1367562559 kcal/mol...
#    Component torsion differs by 4390.90674784 kcal/mol...
#    Component angle differs by 133652.833921 kcal/mol...
#    Component bond differs by 12167.4958149 kcal/mol...
# Molecule 7446 has energy difference of 141454.465284 kcal/mol; out of tolerance.
#    Component nb differs by 15.6112594931 kcal/mol...
#    Component torsion differs by 1207.83553542 kcal/mol...
#    Component angle differs by 133665.666619 kcal/mol...
#    Component bond differs by 6596.57438883 kcal/mol...
# Molecule 7449 has energy difference of 82498.129514 kcal/mol; out of tolerance.
#    Component torsion differs by 4453.07620879 kcal/mol...
#    Component angle differs by 72170.1329061 kcal/mol...
#    Component bond differs by 5877.62730688 kcal/mol...
# Molecule 7452 has energy difference of 128033.001798 kcal/mol; out of tolerance.
#    Component nb differs by 15.8100877386 kcal/mol...
#    Component torsion differs by 1168.06017042 kcal/mol...
#    Component angle differs by 120604.327739 kcal/mol...
#    Component bond differs by 6276.42397686 kcal/mol...
# Molecule 7454 has energy difference of 168212.824205 kcal/mol; out of tolerance.
#    Component nb differs by 33.9157888749 kcal/mol...
#    Component torsion differs by 5463.98118941 kcal/mol...
#    Component angle differs by 152317.253302 kcal/mol...
#    Component bond differs by 10465.505502 kcal/mol...
# Molecule 7455 has energy difference of 72022.2823028 kcal/mol; out of tolerance.
#    Component nb differs by 11.8155503549 kcal/mol...
#    Component torsion differs by 3200.14081868 kcal/mol...
#    Component angle differs by 65293.3939171 kcal/mol...
#    Component bond differs by 3540.56311738 kcal/mol...
# Molecule 7456 has energy difference of 60204.1162636 kcal/mol; out of tolerance.
#    Component torsion differs by 2013.33190493 kcal/mol...
#    Component angle differs by 53210.3590775 kcal/mol...
#    Component bond differs by 4983.3016064 kcal/mol...
# Molecule 7462 has energy difference of 117947.814431 kcal/mol; out of tolerance.
#    Component nb differs by 25.0663030951 kcal/mol...
#    Component torsion differs by 1798.22776187 kcal/mol...
#    Component angle differs by 109258.525676 kcal/mol...
#    Component bond differs by 6916.12729597 kcal/mol...
# Molecule 7467 has energy difference of 157486.28345 kcal/mol; out of tolerance.
#    Component nb differs by 22.7407915613 kcal/mol...
#    Component torsion differs by 2626.65765205 kcal/mol...
#    Component angle differs by 144743.473702 kcal/mol...
#    Component bond differs by 10138.8928875 kcal/mol...
# Molecule 7468 has energy difference of 140136.060309 kcal/mol; out of tolerance.
#    Component nb differs by 36.6622663896 kcal/mol...
#    Component torsion differs by 3938.71850324 kcal/mol...
#    Component angle differs by 127727.89378 kcal/mol...
#    Component bond differs by 8506.11029179 kcal/mol...
# Molecule 7469 has energy difference of 87701.8399805 kcal/mol; out of tolerance.
#    Component nb differs by 8.16482955003 kcal/mol...
#    Component torsion differs by 469.720806589 kcal/mol...
#    Component angle differs by 81050.6750283 kcal/mol...
#    Component bond differs by 6189.60897517 kcal/mol...
# Molecule 7470 has energy difference of 103182.540318 kcal/mol; out of tolerance.
#    Component nb differs by 13.0418556293 kcal/mol...
#    Component torsion differs by 1897.70062124 kcal/mol...
#    Component angle differs by 94429.4998214 kcal/mol...
#    Component bond differs by 6868.3817305 kcal/mol...
# Molecule 7474 has energy difference of 124732.955755 kcal/mol; out of tolerance.
#    Component nb differs by 17.9040500556 kcal/mol...
#    Component torsion differs by 4652.15735001 kcal/mol...
#    Component angle differs by 112504.435822 kcal/mol...
#    Component bond differs by 7594.26663303 kcal/mol...
# Molecule 7475 has energy difference of 49980.1995331 kcal/mol; out of tolerance.
#    Component nb differs by 5.18208535727 kcal/mol...
#    Component torsion differs by 1799.99977231 kcal/mol...
#    Component angle differs by 45718.8464184 kcal/mol...
#    Component bond differs by 2466.53542777 kcal/mol...
# Molecule 7476 has energy difference of 52409.7508024 kcal/mol; out of tolerance.
#    Component nb differs by 5.05508618307 kcal/mol...
#    Component torsion differs by 1637.46916677 kcal/mol...
#    Component angle differs by 46601.5746882 kcal/mol...
#    Component bond differs by 4175.76203359 kcal/mol...
# Molecule 7480 has energy difference of 124340.981961 kcal/mol; out of tolerance.
#    Component nb differs by 17.5765007791 kcal/mol...
#    Component torsion differs by 2354.47314117 kcal/mol...
#    Component angle differs by 115343.959726 kcal/mol...
#    Component bond differs by 6660.12559382 kcal/mol...
# Molecule 7482 has energy difference of 123958.468297 kcal/mol; out of tolerance.
#    Component nb differs by 19.647726876 kcal/mol...
#    Component torsion differs by 4651.23129642 kcal/mol...
#    Component angle differs by 111863.326679 kcal/mol...
#    Component bond differs by 7463.55804848 kcal/mol...
# Molecule 7483 has energy difference of 52678.4384918 kcal/mol; out of tolerance.
#    Component torsion differs by 2997.69376196 kcal/mol...
#    Component angle differs by 45540.3754477 kcal/mol...
#    Component bond differs by 4143.62653134 kcal/mol...
# Molecule 7484 has energy difference of 96105.7723826 kcal/mol; out of tolerance.
#    Component torsion differs by 5269.70549315 kcal/mol...
#    Component angle differs by 84287.182839 kcal/mol...
#    Component bond differs by 6547.39340108 kcal/mol...
# Molecule 7487 has energy difference of 93095.4418571 kcal/mol; out of tolerance.
#    Component nb differs by 26.5449433735 kcal/mol...
#    Component torsion differs by 2657.51301069 kcal/mol...
#    Component angle differs by 86591.5631762 kcal/mol...
#    Component bond differs by 3872.9106136 kcal/mol...
# Molecule 7488 has energy difference of 151594.077009 kcal/mol; out of tolerance.
#    Component nb differs by 14.9908277664 kcal/mol...
#    Component torsion differs by 4707.04754825 kcal/mol...
#    Component angle differs by 138472.119051 kcal/mol...
#    Component bond differs by 8429.90123747 kcal/mol...
# Molecule 7492 has energy difference of 84860.4356909 kcal/mol; out of tolerance.
#    Component torsion differs by 4796.68846369 kcal/mol...
#    Component angle differs by 73984.8533204 kcal/mol...
#    Component bond differs by 6077.5000203 kcal/mol...
# Molecule 7498 has energy difference of 106947.082026 kcal/mol; out of tolerance.
#    Component torsion differs by 5026.97376043 kcal/mol...
#    Component angle differs by 93840.4831192 kcal/mol...
#    Component bond differs by 8079.28916066 kcal/mol...
# Molecule 7500 has energy difference of 104631.327266 kcal/mol; out of tolerance.
#    Component torsion differs by 4891.22468796 kcal/mol...
#    Component angle differs by 91805.2097096 kcal/mol...
#    Component bond differs by 7937.04340575 kcal/mol...
# Molecule 7503 has energy difference of 115187.710027 kcal/mol; out of tolerance.
#    Component nb differs by 15.6651965803 kcal/mol...
#    Component torsion differs by 2885.54976104 kcal/mol...
#    Component angle differs by 106058.198615 kcal/mol...
#    Component bond differs by 6259.62684727 kcal/mol...
# Molecule 7504 has energy difference of 33019.1736864 kcal/mol; out of tolerance.
#    Component torsion differs by 2403.20621561 kcal/mol...
#    Component angle differs by 28338.9712638 kcal/mol...
#    Component bond differs by 2276.57244241 kcal/mol...

# %% [markdown]
# ### 3.C: Focus on the specific atoms responsible for these energy differences
#
# Pull specific molecules with energy differences, focus on those terms responsible for the differences in the energy, and try and find which specific atoms are most responsible for those energies.
#
# Adapting code from github.com/open-forcefield-group/open-forcefield-data, specifically under model systems the substructure depiction and smarts depiction ipython notebooks under Frosst_AlkEthOH.
#
# #### Define utility function for extracting energy of a specified energy term for a specified group of atoms

# %%
import copy
from simtk import openmm, unit
def getValenceEnergyComponent(system, positions, atoms, verbose = False):
    """
    Get the OpenMM valence energy corresponding to a specified set of atoms (bond, angle, torsion).
    
    Parameters
    ----------
    system : simtk.openmm.System
       The OpenMM System object for the molecule
    positions : simtk.unit.Quantity of dimension (natoms,3) with units compatible with angstroms
       The positions of the molecule
    atoms : list or set of int
       The set of atoms in the bond, angle, or torsion.
    verbose : bool (optional)
        Be verbise. Default False. 

    Returns
    -------
    potential : simtk.unit.Quantity with units compatible with kilocalories_per_mole
       The energy of the valence component.
    """
    atoms = set(atoms)
    natoms = len(atoms) # number of atoms
    # Create a copy of the original System object so we can manipulate it
    system = copy.deepcopy(system)
    # Determine Force types to keep
    if natoms == 2:
        forcename = 'HarmonicBondForce'
    elif natoms == 3:
        forcename = 'HarmonicAngleForce'
    elif natoms == 4:
        forcename = 'PeriodicTorsionForce'
    else:
        raise Exception('len(atoms) = %d, but must be in [2,3,4] for bond, angle, or torsion' % len(atoms))
    # Discard Force objects we don't need
    for force_index in reversed(range(system.getNumForces())):
        if system.getForce(force_index).__class__.__name__ != forcename:
            system.removeForce(force_index)

    # Report on constraints
    if forcename == 'HarmonicBondForce':
        for constraint_index in range(system.getNumConstraints()):
            [i, j, r0] = system.getConstraintParameters(constraint_index)
            if set([i,j]) == atoms:
                print('Bond is constrained')        
            
    # Zero out force components that don't involve the atoms
    for force_index in range(system.getNumForces()):
        force = system.getForce(force_index)
        if forcename == 'HarmonicBondForce':
            for param_index in range(force.getNumBonds()):
                [i, j, r0, K] = force.getBondParameters(param_index)
                if set([i,j]) != atoms:
                    K *= 0
                else:
                    if verbose: print('Match found: bond parameter %d : r0 = %s, K = %s' % (param_index, str(r0), str(K)))
                force.setBondParameters(param_index, i, j, r0, K)
        elif forcename == 'HarmonicAngleForce':
            for param_index in range(force.getNumAngles()):
                [i, j, k, theta0, K] = force.getAngleParameters(param_index)
                if set([i,j,k]) != atoms:
                    K *= 0
                else:
                    if verbose: print('Match found: angle parameter %d : theta0 = %s, K = %s' % (param_index, str(theta0), str(K)))
                force.setAngleParameters(param_index, i, j, k, theta0, K)
        elif forcename == 'PeriodicTorsionForce':
            for param_index in range(force.getNumTorsions()):
                [i, j, k, l, periodicity, phase, K] = force.getTorsionParameters(param_index)
                if set([i,j,k,l]) != atoms:
                    K *= 0
                else:
                    if verbose: print('Match found: torsion parameter %d : periodicity = %s, phase = %s, K = %s' % (param_index, str(periodicity), str(phase), str(K)))
                force.setTorsionParameters(param_index, i, j, k, l, periodicity, phase, K)
    # Compute energy
    platform = openmm.Platform.getPlatformByName('Reference')
    integrator = openmm.VerletIntegrator(1.0 * unit.femtoseconds)
    context = openmm.Context(system, integrator, platform)
    context.setPositions(positions)
    potential = context.getState(getEnergy=True).getPotentialEnergy()
    del context, integrator, system
    # Return energy
    return potential

# %% [markdown]
# #### Find parameters that could be responsible for the differences, then check energies on atoms labeled by those parameters
#
# Use the forcefield labeling feature to see which parameters/SMIRKS are applied to those force terms in the problematic molecule(s), then pull atoms labeled by those force terms and see which ones are responsible for the differences.
#
# Note that currently this does no checking for energy differences due to nonbonded parameters.

# %% [markdown]
# ### Add a simple depiction of different places a particular problematic SMIRKS matches the test molecule
#
# This makes no attempt to look at all problematic SMIRKS, nor does it focus on only the problematic instances of those problematic SMIRKS. It just displays all places that SMIRKS occurs in the selected molecule.

# %%
# Pick a specific problematic molecule to look at for now
targetmol = components_out_of_tolerance.keys()[0] #Just first molecule which is out of tolerance

# Convert component names to force names
forcename = { 'bond':'HarmonicBondGenerator', 'angle':'HarmonicAngleGenerator', 'torsion':'PeriodicTorsionGenerator', 'nb':'NonbondedGenerator'}

# Pull oemol and see what parameters are used
oemol = oemols_tripos[targetmol]
molecule_labels = ff.labelMolecules( [oemol])

# Generate OpenMM systems from SMIRFF and AMBER for this molecule
# First, system from smirff
topology = generateTopologyFromOEMol(oemol)
smirff_system = ff.createSystem(topology, [oemol])
# Now, generate system from AMBER files
topology, amber_system, positions = create_system_from_amber( 'zinc_frosst_amber/zinc%s.prmtop' % targetmol, 'zinc_frosst_amber/zinc%s.crd' % targetmol, verbose = False )

# For this molecule, loop over components out of tolerance and look at energies for specific atoms
# to find where the big differences occur
print("Examining energy differences for valence terms with significant differences in molecule number %s" % targetmol)
problem_smirks = {}
problem_pids = {}
good_smirks = {}
good_pids = {}
compnames = components_out_of_tolerance[targetmol]
if 'nb' in compnames: compnames.remove('nb') # Skip nonbonded params -- no code for this here
for comp in compnames:
    print("\nEnergy differences for %s terms:" % comp)
    force = forcename[comp]
    problem_smirks[comp] = {}
    problem_pids[comp] = {}
    good_smirks[comp] = {}
    good_pids[comp] = {}
    # Build list of all sets of atoms involved in this force type
    atom_lists = [ molecule_labels[0][force][idx][0] for idx in range(len(molecule_labels[0][force]))]
    smirks_list = [ molecule_labels[0][force][idx][2] for idx in range(len(molecule_labels[0][force]))]
    pid_list = [ molecule_labels[0][force][idx][1] for idx in range(len(molecule_labels[0][force]))]
    # Use utility functionality above to cross-check energy of this force term for these atoms
    for idx,atomgroup in enumerate(atom_lists):
        if len(atomgroup) > 1: # Skip nonbonded terms as we're looking at valence energies
            #TO DO: the valence energy function uses a set to compare terms, which is not correct since torsion 1, 2, 3. 4
            # and 3, 4, 1, 2 are not the same
            smirff_term = getValenceEnergyComponent( smirff_system, positions, atomgroup)
            amber_term = getValenceEnergyComponent( amber_system, positions, atomgroup)
            diff = np.abs(smirff_term-amber_term)
            #print(atomgroup, "diff=", diff)
            #print(smirff_term, amber_term)
            
            smirks = smirks_list[idx]
            pid = pid_list[idx]
            
            #When we find a difference, get what smirks and param id are responsible and accumulate stats
            if diff > component_tol:
                print("    Significant difference (%s) for %s (%s, parameter %s)" % (diff, str(atomgroup), smirks, pid))
                if not smirks in problem_smirks[comp]:
                    problem_smirks[comp][smirks]=1
                    problem_pids[comp][pid]=1
                else:
                    problem_smirks[comp][smirks]+=1
                    problem_pids[comp][pid]+=1
                    
                #next just print useful info about when/where different, maybe depict
            # If it's not significantly different
            else:
                #print("    Not different for %s (%s, parameter %s)" % (str(atomgroup), smirks, pid))
                if not smirks in good_smirks[comp]:
                    good_smirks[comp][smirks]=1
                    good_pids[comp][pid]=1
                else:
                    good_smirks[comp][smirks]+=1
                    good_pids[comp][pid]+=1
                    
    # Print info on population of terms which are problematic
    allsmirks = set(problem_smirks[comp].keys()).union(set(good_smirks[comp].keys()))
    for smirks in allsmirks:
        goodct = 0
        probct = 0
        if smirks in problem_smirks[comp]:
            probct = problem_smirks[comp][smirks]
        if smirks in good_smirks[comp]:
            goodct = good_smirks[comp][smirks]
        print('\n    SMIRKS %s is problematic in %d cases but is OK in %d cases' % (smirks, probct, goodct))
            
# Note that the above doesn't check nonbonded parameters
# Out:
# Examining energy differences for valence terms with significant differences in molecule number 0
#
# Energy differences for torsion terms:
#     Significant difference (22.7497708964 kJ/mol) for [1, 2, 4, 21] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7500122728 kJ/mol) for [16, 0, 1, 18] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (64.2229478732 kJ/mol) for [3, 2, 4, 21] ([*:1]~[*:2]~[#6:3]~[#8:4], parameter i1)
#     Significant difference (29.2558907758 kJ/mol) for [9, 8, 7, 25] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (23.1263034387 kJ/mol) for [7, 8, 9, 10] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7512082599 kJ/mol) for [2, 1, 0, 17] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (29.2554940564 kJ/mol) for [6, 7, 8, 9] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (64.2261393877 kJ/mol) for [3, 2, 1, 19] ([*:1]~[*:2]~[#6:3]~[#8:4], parameter i1)
#     Significant difference (22.7539768837 kJ/mol) for [16, 0, 1, 19] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7520636663 kJ/mol) for [6, 5, 4, 20] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7528753621 kJ/mol) for [4, 2, 1, 18] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (24.6767393239 kJ/mol) for [7, 6, 5, 22] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7493486229 kJ/mol) for [20, 4, 5, 23] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7507663622 kJ/mol) for [2, 4, 5, 22] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7506460233 kJ/mol) for [21, 4, 5, 22] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (24.9187908136 kJ/mol) for [22, 5, 6, 24] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (17.2182080788 kJ/mol) for [10, 11, 12, 13] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (20.4913865364 kJ/mol) for [4, 5, 6, 7] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (20.3515178242 kJ/mol) for [4, 5, 6, 24] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (64.2304389525 kJ/mol) for [3, 2, 1, 18] ([*:1]~[*:2]~[#6:3]~[#8:4], parameter i1)
#     Significant difference (22.7479739364 kJ/mol) for [15, 0, 1, 18] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7525550182 kJ/mol) for [1, 2, 4, 20] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7500876076 kJ/mol) for [6, 5, 4, 21] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7467941283 kJ/mol) for [17, 0, 1, 19] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7509163635 kJ/mol) for [4, 2, 1, 19] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (64.2295464434 kJ/mol) for [3, 2, 4, 20] ([*:1]~[*:2]~[#6:3]~[#8:4], parameter i1)
#     Significant difference (22.7500876076 kJ/mol) for [2, 4, 5, 23] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (30.3259705895 kJ/mol) for [12, 13, 14, 26] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#     Significant difference (22.7530334918 kJ/mol) for [2, 1, 0, 15] ([*:1]~[#6:2]~[#6:3]~[*:4], parameter t1)
#
#     SMIRKS [*:1]~[*:2]~[#6:3]~[#8:4] is problematic in 4 cases but is OK in 2 cases
#
#     SMIRKS [*:1]~[#6:2]~[#6:3]~[*:4] is problematic in 25 cases but is OK in 19 cases
#
# Energy differences for angle terms:
#     Significant difference (7636.51193463 kJ/mol) for [26, 14, 27] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7635.82870963 kJ/mol) for [0, 1, 2] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.3219613 kJ/mol) for [5, 4, 20] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (20646.8943413 kJ/mol) for [7, 8, 9] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (9175.90247833 kJ/mol) for [8, 7, 25] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.20754692 kJ/mol) for [16, 0, 17] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.73578295 kJ/mol) for [15, 0, 16] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.72700499 kJ/mol) for [15, 0, 17] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.56308067 kJ/mol) for [18, 1, 19] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.26090562 kJ/mol) for [26, 14, 28] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (9176.24678664 kJ/mol) for [5, 6, 7] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.8185967 kJ/mol) for [2, 4, 21] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (20646.3640448 kJ/mol) for [9, 10, 11] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.32157357 kJ/mol) for [20, 4, 21] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.74306933 kJ/mol) for [2, 4, 20] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.65743594 kJ/mol) for [22, 5, 23] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.15293462 kJ/mol) for [5, 4, 21] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (20646.542124 kJ/mol) for [12, 13, 14] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.74777881 kJ/mol) for [2, 4, 5] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.16684595 kJ/mol) for [27, 14, 28] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.7236776 kJ/mol) for [6, 5, 22] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.8185967 kJ/mol) for [6, 5, 23] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.46365212 kJ/mol) for [2, 1, 18] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.34347811 kJ/mol) for [2, 1, 19] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (9176.62151729 kJ/mol) for [6, 7, 8] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (9176.26792121 kJ/mol) for [7, 6, 24] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.57909642 kJ/mol) for [0, 1, 18] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (20646.3640448 kJ/mol) for [10, 11, 12] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (9176.29578074 kJ/mol) for [1, 2, 4] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7635.31418694 kJ/mol) for [4, 5, 6] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (9176.996574 kJ/mol) for [5, 6, 24] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (9177.08668823 kJ/mol) for [6, 7, 25] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (20646.7679378 kJ/mol) for [8, 9, 10] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.63104443 kJ/mol) for [1, 0, 15] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (20646.8510516 kJ/mol) for [11, 12, 13] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.99320383 kJ/mol) for [13, 14, 26] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.00548367 kJ/mol) for [4, 5, 22] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.78343021 kJ/mol) for [13, 14, 27] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.15293462 kJ/mol) for [4, 5, 23] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7636.60247001 kJ/mol) for [13, 14, 28] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7635.94546247 kJ/mol) for [1, 0, 16] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.07186483 kJ/mol) for [1, 0, 17] ([*:1]~[*:2]~[*:3], parameter a0)
#     Significant difference (7637.32619417 kJ/mol) for [0, 1, 19] ([*:1]~[*:2]~[*:3], parameter a0)
#
#     SMIRKS [#6:1]~[#6:2]~[#8:3] is problematic in 0 cases but is OK in 2 cases
#
#     SMIRKS [*:1]~[*:2]~[*:3] is problematic in 43 cases but is OK in 0 cases
#
# Energy differences for bond terms:
#     Significant difference (159.534895886 kJ/mol) for [10, 11] ([#6:1]~[#6:2], parameter b1)
#     Significant difference (1770.61180978 kJ/mol) for [7, 25] ([*:1]~[*:2], parameter b0)
#     Significant difference (159.45806177 kJ/mol) for [8, 9] ([#6:1]~[#6:2], parameter b1)
#     Significant difference (1732.29253044 kJ/mol) for [0, 16] ([*:1]~[*:2], parameter b0)
#     Significant difference (1770.60446778 kJ/mol) for [6, 24] ([*:1]~[*:2], parameter b0)
#     Significant difference (1732.43036566 kJ/mol) for [5, 23] ([*:1]~[*:2], parameter b0)
#     Significant difference (1732.15388074 kJ/mol) for [14, 27] ([*:1]~[*:2], parameter b0)
#     Significant difference (46.4635824585 kJ/mol) for [6, 7] ([#6:1]~[#6:2], parameter b1)
#     Significant difference (1732.47041451 kJ/mol) for [0, 15] ([*:1]~[*:2], parameter b0)
#     Significant difference (159.533944143 kJ/mol) for [12, 13] ([#6:1]~[#6:2], parameter b1)
#     Significant difference (1732.64899034 kJ/mol) for [0, 17] ([*:1]~[*:2], parameter b0)
#     Significant difference (1732.29644255 kJ/mol) for [5, 22] ([*:1]~[*:2], parameter b0)
#     Significant difference (1732.51182625 kJ/mol) for [14, 28] ([*:1]~[*:2], parameter b0)
#     Significant difference (23.9112937771 kJ/mol) for [9, 10] ([#6:1]~[#6:2], parameter b1)
#     Significant difference (1732.57030318 kJ/mol) for [1, 19] ([*:1]~[*:2], parameter b0)
#     Significant difference (1312.55503127 kJ/mol) for [2, 3] ([*:1]~[*:2], parameter b0)
#     Significant difference (2080.56654742 kJ/mol) for [4, 20] ([*:1]~[*:2], parameter b0)
#     Significant difference (23.9112937771 kJ/mol) for [11, 12] ([#6:1]~[#6:2], parameter b1)
#     Significant difference (2080.51725069 kJ/mol) for [1, 18] ([*:1]~[*:2], parameter b0)
#     Significant difference (1732.33472565 kJ/mol) for [14, 26] ([*:1]~[*:2], parameter b0)
#     Significant difference (1732.43036566 kJ/mol) for [4, 21] ([*:1]~[*:2], parameter b0)
#
#     SMIRKS [*:1]~[*:2] is problematic in 15 cases but is OK in 0 cases
#
#     SMIRKS [#6:1]~[#6:2] is problematic in 6 cases but is OK in 7 cases

# %%
# For demo, pick some SMIRKS which is problematic at least some of the time and show where it appears in the molecule

import openeye.oechem as oechem
import openeye.oedepict as oedepict
from IPython.display import display

def depict(mol, width=500, height=200):
    from IPython.display import Image
    dopt = oedepict.OEPrepareDepictionOptions()
    dopt.SetDepictOrientation( oedepict.OEDepictOrientation_Horizontal)
    oedepict.OEPrepareDepiction(mol, dopt)
    opts = oedepict.OE2DMolDisplayOptions(width, height, oedepict.OEScale_AutoScale)
    disp = oedepict.OE2DMolDisplay(mol, opts)
    ofs = oechem.oeosstream()
    oedepict.OERenderMolecule(ofs, 'png', disp)
    ofs.flush()
    return Image(data = "".join(ofs.str()))

def depictMatch(mol, match, supH = True, width=500, height=200):
    from IPython.display import Image
    dopt = oedepict.OEPrepareDepictionOptions()
    dopt.SetDepictOrientation( oedepict.OEDepictOrientation_Horizontal)
    dopt.SetSuppressHydrogens(supH)
    oedepict.OEPrepareDepiction(mol, dopt)
    opts = oedepict.OE2DMolDisplayOptions(width, height, oedepict.OEScale_AutoScale)
    disp = oedepict.OE2DMolDisplay(mol, opts)
    hstyle = oedepict.OEHighlightStyle_Color
    hcolor = oechem.OEColor(oechem.OELightBlue)
    oedepict.OEAddHighlighting(disp, hcolor, hstyle, match)
    ofs = oechem.oeosstream()
    oedepict.OERenderMolecule(ofs, 'png', disp)
    ofs.flush()
    return Image(data = "".join(ofs.str()))

# Initialize query
qmol = oechem.OEQMol()

# Grab molecule and problematic SMIRKS
oemol = oemols_tripos[targetmol]
smirks_list = problem_smirks['bond'].keys()
smirks_list.sort()
smirks=smirks_list[0]
# Prep search
oechem.OEParseSmarts( qmol, smirks)
ss = oechem.OESubSearch(qmol)

# Search molecule, depict
oechem.OEPrepareSearch(oemol, ss)
for match in ss.Match(oemol, True): #Some torsions may need unique = False
    display( depictMatch(oemol, match))
